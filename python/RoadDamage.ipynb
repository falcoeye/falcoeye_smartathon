# %%
# cloning the private repo 
# !git clone https://falcoeye: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@github.com/falcoeye/falcoeye_smartathon.git
# Out:
# Cloning into 'falcoeye_smartathon'...
# remote: Enumerating objects: 87, done.
# remote: Total 87 (delta 0), reused 0 (delta 0), pack-reused 87
# Unpacking objects: 100% (87/87), 71.46 MiB | 8.67 MiB/s, done.

# %%
# move to the python folder
cd 'falcoeye_smartathon/python'
# Out:
# [Errno 2] No such file or directory: 'falcoeye_smartathon/python'
# /content/falcoeye_smartathon/python

# %%
# !mkdir data
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# for downloading from google drive
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...

# %%
# Download d0 checkpoints
# !gdown https://drive.google.com/uc?id=1TCs_snVnUcBAmovyuNfCc8pHk8uR1ENw --output checkpoints/d0_.pth
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TCs_snVnUcBAmovyuNfCc8pHk8uR1ENw
# To: /content/falcoeye_smartathon/python/checkpoints/d0_.pth
# 100% 46.7M/46.7M [00:00<00:00, 153MB/s]

# %%
# Download the video provided in the smartathon with no gps info
# !gdown https://drive.google.com/uc?id=1JERWkeUy_ryMh_Ran4kf5t4sCRR1zuRL  --output smartathon_no_gps.mp4
# Dowanload the video we recorded in Riyadh with gps info
# !gdown https://drive.google.com/uc?id=1dWKdXDvP29oKPtzwbwxLubHko-Od7aBF  --output riyadh_with_gps.mp4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JERWkeUy_ryMh_Ran4kf5t4sCRR1zuRL
# To: /content/falcoeye_smartathon/python/smartathon_no_gps.mp4
# 100% 279M/279M [00:01<00:00, 213MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1dWKdXDvP29oKPtzwbwxLubHko-Od7aBF
# To: /content/falcoeye_smartathon/python/riyadh_with_gps.mp4
# 100% 213M/213M [00:01<00:00, 131MB/s]

# %%
# Installing needed libraries
# !apt-get install tesseract-ocr
# !pip install -r requirements.txt
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 23 not upgraded.
# Need to get 4,850 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1 [1,598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr amd64 4.1.1-2build2 [262 kB]
# Fetched 4,850 kB in 0s (28.9 MB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 129501 files and directories currently installed.)
# ...

# %%
# Run the video with no gps on the smartathon video
# !python run.py --checkpoint checkpoints/d0_.pth \
 --file smartathon_no_gps.mp4 \
 --backbone tf_efficientdet_d0 \
 --output data/smartathon \
 --sample_every 1 \
 --use-cuda \
 --no-gps \
 --video \
 --draw \
 --cracks_imgs
# Out:
# 2023-01-18 15:12:11.762 INFO run - initialize: Using cuda device
# 2023-01-18 15:12:11.955 INFO helpers - load_state_dict: Loaded state_dict_ema from checkpoint 'checkpoints/d0_.pth'
# 2023-01-18 15:12:13.529 INFO run - main_video: Handling smartathon_no_gps.mp4
# 2023-01-18 15:12:13.554 INFO run - open: Opening video with 823, frame rate 23.976023976023978, and  Video diamter 2202.9071700822983
# 2023-01-18 15:12:13.554 INFO run - main_video: Writing prediction video into data/smartathon/smartathon_no_gps_pred.mp4
# 2023-01-18 15:12:16.249 INFO run - main_video: 1/823 smartathon_no_gps.mp4,1,814,553,933,609,None,None,4,131.795,0.06
# 2023-01-18 15:12:16.380 INFO run - main_video: 2/823 smartathon_no_gps.mp4,2,1070,663,1346,757,None,None,4,291.616,0.132
# 2023-01-18 15:12:17.160 INFO run - main_video: 3/823 smartathon_no_gps.mp4,3,794,572,918,635,None,None,4,139.318,0.063
# ...

# %%
# Run the video with gps info
# !python run.py --checkpoint checkpoints/d0_.pth \
 --file riyadh_with_gps.mp4 \
 --backbone tf_efficientdet_d0 \
 --output data/riyadh \
 --sample_every 1 \
 --use-cuda \
 --video \
 --draw \
 --cracks_imgs
# Out:
# 2023-01-18 15:13:44.454 INFO run - initialize: Using cuda device
# 2023-01-18 15:13:44.644 INFO helpers - load_state_dict: Loaded state_dict_ema from checkpoint 'checkpoints/d0_.pth'
# 2023-01-18 15:13:46.218 INFO run - main_video: Handling riyadh_with_gps.mp4
# 2023-01-18 15:13:46.222 INFO run - open: Opening video with 2250, frame rate 30.0, and  Video diamter 3240.0
# 2023-01-18 15:13:46.223 INFO run - main_video: Writing prediction video into data/riyadh/riyadh_with_gps_pred.mp4
# 2023-01-18 15:13:49.612 INFO run - main_video: 1/2250
# 2023-01-18 15:13:50.005 INFO run - main_video: 2/2250
# 2023-01-18 15:13:51.041 INFO run - main_video: 3/2250
# 2023-01-18 15:13:51.395 INFO run - main_video: 4/2250
# 2023-01-18 15:13:51.755 INFO run - main_video: 5/2250
# 2023-01-18 15:13:52.112 INFO run - main_video: 6/2250
# 2023-01-18 15:13:52.461 INFO run - main_video: 7/2250
# 2023-01-18 15:13:52.812 INFO run - main_video: 8/2250
# 2023-01-18 15:13:53.157 INFO run - main_video: 9/2250
# ...

# %%
# visualizing the results
import pandas as pd
import plotly.express as px

column = "normalized_length"
range_color = [0,5]
df = pd.read_csv("data/riyadh/riyadh_with_gps.csv")
fig = px.density_mapbox(df, lat='latitude', lon='longitude', z=column,
                        mapbox_style="open-street-map", width=920, height=720,range_color=range_color)
fig.update_layout(
    autosize=True, hovermode='closest',
    mapbox = {'zoom': 15},
    showlegend = False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
